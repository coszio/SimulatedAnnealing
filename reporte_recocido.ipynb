# %%
from SimAnnealing import SimAnnealing
import matplotlib.pyplot as plt

# %%
sa = SimAnnealing(n_cities=25, n_travelers=5, beta=1.1, alpha=0.001, min_temp=0.0001)
sa.run()

plt.xlabel('iteraciones')
plt.ylabel('fitness')
plt.plot(range(len(sa.best_fitnesses)), sa.best_fitnesses)

plt.show()

sa.plot_solution()
